# %% [markdown]
# # Inventory & Discount Management
#
# This module converts sales forecasts into actionable business decisions,
# including restocking and discount recommendations.

# %%
import pandas as pd
from inventory_logic import inventory_and_discount_logic

forecast = pd.read_csv(r"..\..\data\outputs\sales_forecast.csv")
stock = pd.read_csv(r"..\..\data\raw\inventory\current_stock.csv")

forecast.head(), stock.head()
# Out:
# (         date product_id  actual_sales  predicted_sales
#  0  2009-12-01      22086       1327.37       923.637492
#  1  2009-12-01      47566         27.90        91.592777
#  2  2009-12-01      84879       1919.28       489.579309
#  3  2009-12-01     85099B        326.85       473.966017
#  4  2009-12-01     85123A        702.42      1193.365752,
#    product_id  current_stock
#  0      22086           1680
#  1      22423            756
#  2      23843        1133930
#  3      47566            728
#  4      84879           1974)

# %%
inv, disc = inventory_and_discount_logic(
    forecast_df=forecast[["date","product_id","predicted_sales"]],
    stock_df=stock
)

inv, disc
# Out:
# d:\PROJECTS\AI_Powered_Retail_Decision_Support_System\modules\inventory_management\inventory_logic.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_df["date"] = pd.to_datetime(forecast_df["date"])
# (  product_id decision  recommended_order                          reason
#  0      22086  REORDER               4191  Predicted demand exceeds stock
#  1      22423  REORDER               3835  Predicted demand exceeds stock
#  2      23843       OK                  0                Stock sufficient
#  3      47566       OK                  0                Stock sufficient
#  4      84879  REORDER               1149  Predicted demand exceeds stock
#  5     85099B  REORDER                394  Predicted demand exceeds stock
# ...
